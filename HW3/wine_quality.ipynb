# %%
import keras

# %%
import numpy as np 
import pandas as pd
from sklearn.model_selection import train_test_split

from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import EarlyStopping, ModelCheckpoint

from sklearn.preprocessing import StandardScaler

SEED = 2017

# %%
data = pd.read_csv('Data/winequality-red.csv', sep=';')
y = data['quality']
X = data.drop(['quality'], axis=1)
data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=SEED)

# %%
#normalize data to sample mean = 0, sample variance = 1
scaler = StandardScaler().fit(X_train)
X_train = pd.DataFrame(scaler.transform(X_train))
X_test = pd.DataFrame(scaler.transform(X_test))

# %%
batch_size = 64
n_epochs = 200
lr = 0.01

model = Sequential()
# First hidden layer with 100 hidden units
model.add(Dense(512, input_dim=X_train.shape[1], activation='relu')) 
# Output layer
model.add(Dense(1, activation='linear'))

# Compile model
model.compile(loss='mse', optimizer="adam")

# %%
callbacks = [
             EarlyStopping(monitor='val_loss', patience=20, verbose=2)
            ]

# %%
model.fit(X_train.values, y_train, batch_size=64, epochs=n_epochs, validation_split=0.2,     
             verbose=2, callbacks=callbacks)
# Out:
# Epoch 1/200
# 16/16 - 0s - loss: 27.0789 - val_loss: 19.6190 - 443ms/epoch - 28ms/step
# Epoch 2/200
# 16/16 - 0s - loss: 15.0869 - val_loss: 10.3344 - 51ms/epoch - 3ms/step
# Epoch 3/200
# 16/16 - 0s - loss: 7.3438 - val_loss: 4.7886 - 52ms/epoch - 3ms/step
# Epoch 4/200
# 16/16 - 0s - loss: 3.6602 - val_loss: 2.6499 - 51ms/epoch - 3ms/step
# Epoch 5/200
# 16/16 - 0s - loss: 2.5393 - val_loss: 2.0942 - 52ms/epoch - 3ms/step
# Epoch 6/200
# 16/16 - 0s - loss: 2.1836 - val_loss: 1.8311 - 44ms/epoch - 3ms/step
# Epoch 7/200
# 16/16 - 0s - loss: 1.9427 - val_loss: 1.6932 - 45ms/epoch - 3ms/step
# Epoch 8/200
# 16/16 - 0s - loss: 1.7853 - val_loss: 1.5771 - 43ms/epoch - 3ms/step
# Epoch 9/200
# 16/16 - 0s - loss: 1.6632 - val_loss: 1.4685 - 44ms/epoch - 3ms/step
# Epoch 10/200
# 16/16 - 0s - loss: 1.5516 - val_loss: 1.3897 - 46ms/epoch - 3ms/step
# Epoch 11/200
# 16/16 - 0s - loss: 1.4515 - val_loss: 1.3107 - 44ms/epoch - 3ms/step
# Epoch 12/200
# 16/16 - 0s - loss: 1.3604 - val_loss: 1.2381 - 49ms/epoch - 3ms/step
# Epoch 13/200
# 16/16 - 0s - loss: 1.2814 - val_loss: 1.1756 - 49ms/epoch - 3ms/step
# Epoch 14/200
# 16/16 - 0s - loss: 1.2073 - val_loss: 1.1059 - 47ms/epoch - 3ms/step
# Epoch 15/200
# 16/16 - 0s - loss: 1.1314 - val_loss: 1.0464 - 47ms/epoch - 3ms/step
# Epoch 16/200
# 16/16 - 0s - loss: 1.0700 - val_loss: 0.9928 - 46ms/epoch - 3ms/step
# Epoch 17/200
# 16/16 - 0s - loss: 1.0094 - val_loss: 0.9414 - 46ms/epoch - 3ms/step
# Epoch 18/200
# 16/16 - 0s - loss: 0.9531 - val_loss: 0.8954 - 45ms/epoch - 3ms/step
# Epoch 19/200
# 16/16 - 0s - loss: 0.9014 - val_loss: 0.8521 - 51ms/epoch - 3ms/step
# Epoch 20/200
# 16/16 - 0s - loss: 0.8583 - val_loss: 0.8142 - 47ms/epoch - 3ms/step
# Epoch 21/200
# 16/16 - 0s - loss: 0.8129 - val_loss: 0.7757 - 52ms/epoch - 3ms/step
# Epoch 22/200
# 16/16 - 0s - loss: 0.7667 - val_loss: 0.7469 - 53ms/epoch - 3ms/step
# Epoch 23/200
# 16/16 - 0s - loss: 0.7354 - val_loss: 0.7115 - 51ms/epoch - 3ms/step
# Epoch 24/200
# 16/16 - 0s - loss: 0.6999 - val_loss: 0.6874 - 47ms/epoch - 3ms/step
# Epoch 25/200
# 16/16 - 0s - loss: 0.6702 - val_loss: 0.6628 - 45ms/epoch - 3ms/step
# Epoch 26/200
# 16/16 - 0s - loss: 0.6411 - val_loss: 0.6373 - 46ms/epoch - 3ms/step
# Epoch 27/200
# 16/16 - 0s - loss: 0.6163 - val_loss: 0.6149 - 41ms/epoch - 3ms/step
# Epoch 28/200
# 16/16 - 0s - loss: 0.5923 - val_loss: 0.5999 - 44ms/epoch - 3ms/step
# Epoch 29/200
# 16/16 - 0s - loss: 0.5715 - val_loss: 0.5794 - 44ms/epoch - 3ms/step
# Epoch 30/200
# 16/16 - 0s - loss: 0.5513 - val_loss: 0.5624 - 44ms/epoch - 3ms/step
# Epoch 31/200
# 16/16 - 0s - loss: 0.5331 - val_loss: 0.5576 - 43ms/epoch - 3ms/step
# Epoch 32/200
# 16/16 - 0s - loss: 0.5120 - val_loss: 0.5363 - 44ms/epoch - 3ms/step
# Epoch 33/200
# 16/16 - 0s - loss: 0.5013 - val_loss: 0.5280 - 55ms/epoch - 3ms/step
# Epoch 34/200
# 16/16 - 0s - loss: 0.4868 - val_loss: 0.5204 - 55ms/epoch - 3ms/step
# Epoch 35/200
# 16/16 - 0s - loss: 0.4752 - val_loss: 0.5060 - 50ms/epoch - 3ms/step
# Epoch 36/200
# 16/16 - 0s - loss: 0.4610 - val_loss: 0.5006 - 47ms/epoch - 3ms/step
# Epoch 37/200
# 16/16 - 0s - loss: 0.4519 - val_loss: 0.4883 - 43ms/epoch - 3ms/step
# Epoch 38/200
# 16/16 - 0s - loss: 0.4415 - val_loss: 0.4876 - 45ms/epoch - 3ms/step
# Epoch 39/200
# 16/16 - 0s - loss: 0.4321 - val_loss: 0.4743 - 44ms/epoch - 3ms/step
# Epoch 40/200
# 16/16 - 0s - loss: 0.4228 - val_loss: 0.4752 - 42ms/epoch - 3ms/step
# Epoch 41/200
# 16/16 - 0s - loss: 0.4150 - val_loss: 0.4630 - 44ms/epoch - 3ms/step
# Epoch 42/200
# 16/16 - 0s - loss: 0.4092 - val_loss: 0.4636 - 48ms/epoch - 3ms/step
# Epoch 43/200
# 16/16 - 0s - loss: 0.4028 - val_loss: 0.4606 - 43ms/epoch - 3ms/step
# Epoch 44/200
# 16/16 - 0s - loss: 0.3949 - val_loss: 0.4513 - 53ms/epoch - 3ms/step
# Epoch 45/200
# 16/16 - 0s - loss: 0.3888 - val_loss: 0.4484 - 63ms/epoch - 4ms/step
# Epoch 46/200
# 16/16 - 0s - loss: 0.3863 - val_loss: 0.4392 - 52ms/epoch - 3ms/step
# Epoch 47/200
# 16/16 - 0s - loss: 0.3808 - val_loss: 0.4491 - 46ms/epoch - 3ms/step
# Epoch 48/200
# 16/16 - 0s - loss: 0.3775 - val_loss: 0.4488 - 51ms/epoch - 3ms/step
# Epoch 49/200
# 16/16 - 0s - loss: 0.3725 - val_loss: 0.4386 - 43ms/epoch - 3ms/step
# Epoch 50/200
# 16/16 - 0s - loss: 0.3672 - val_loss: 0.4290 - 42ms/epoch - 3ms/step
# Epoch 51/200
# 16/16 - 0s - loss: 0.3650 - val_loss: 0.4287 - 40ms/epoch - 3ms/step
# Epoch 52/200
# 16/16 - 0s - loss: 0.3632 - val_loss: 0.4331 - 41ms/epoch - 3ms/step
# Epoch 53/200
# 16/16 - 0s - loss: 0.3576 - val_loss: 0.4250 - 51ms/epoch - 3ms/step
# Epoch 54/200
# 16/16 - 0s - loss: 0.3523 - val_loss: 0.4187 - 50ms/epoch - 3ms/step
# Epoch 55/200
# 16/16 - 0s - loss: 0.3519 - val_loss: 0.4204 - 45ms/epoch - 3ms/step
# Epoch 56/200
# 16/16 - 0s - loss: 0.3470 - val_loss: 0.4264 - 39ms/epoch - 2ms/step
# Epoch 57/200
# 16/16 - 0s - loss: 0.3453 - val_loss: 0.4212 - 40ms/epoch - 2ms/step
# Epoch 58/200
# 16/16 - 0s - loss: 0.3398 - val_loss: 0.4169 - 44ms/epoch - 3ms/step
# Epoch 59/200
# 16/16 - 0s - loss: 0.3389 - val_loss: 0.4168 - 43ms/epoch - 3ms/step
# Epoch 60/200
# 16/16 - 0s - loss: 0.3354 - val_loss: 0.4194 - 42ms/epoch - 3ms/step
# Epoch 61/200
# 16/16 - 0s - loss: 0.3338 - val_loss: 0.4180 - 44ms/epoch - 3ms/step
# Epoch 62/200
# 16/16 - 0s - loss: 0.3307 - val_loss: 0.4110 - 45ms/epoch - 3ms/step
# Epoch 63/200
# 16/16 - 0s - loss: 0.3332 - val_loss: 0.4201 - 43ms/epoch - 3ms/step
# Epoch 64/200
# 16/16 - 0s - loss: 0.3298 - val_loss: 0.4091 - 46ms/epoch - 3ms/step
# Epoch 65/200
# 16/16 - 0s - loss: 0.3321 - val_loss: 0.4043 - 45ms/epoch - 3ms/step
# Epoch 66/200
# 16/16 - 0s - loss: 0.3269 - val_loss: 0.4201 - 45ms/epoch - 3ms/step
# Epoch 67/200
# 16/16 - 0s - loss: 0.3172 - val_loss: 0.4029 - 43ms/epoch - 3ms/step
# Epoch 68/200
# 16/16 - 0s - loss: 0.3161 - val_loss: 0.4132 - 44ms/epoch - 3ms/step
# Epoch 69/200
# 16/16 - 0s - loss: 0.3172 - val_loss: 0.4018 - 44ms/epoch - 3ms/step
# Epoch 70/200
# 16/16 - 0s - loss: 0.3155 - val_loss: 0.4137 - 47ms/epoch - 3ms/step
# Epoch 71/200
# 16/16 - 0s - loss: 0.3219 - val_loss: 0.4142 - 44ms/epoch - 3ms/step
# Epoch 72/200
# 16/16 - 0s - loss: 0.3171 - val_loss: 0.4077 - 44ms/epoch - 3ms/step
# Epoch 73/200
# 16/16 - 0s - loss: 0.3134 - val_loss: 0.3956 - 46ms/epoch - 3ms/step
# Epoch 74/200
# 16/16 - 0s - loss: 0.3135 - val_loss: 0.4023 - 45ms/epoch - 3ms/step
# Epoch 75/200
# 16/16 - 0s - loss: 0.3163 - val_loss: 0.3991 - 46ms/epoch - 3ms/step
# Epoch 76/200
# 16/16 - 0s - loss: 0.3064 - val_loss: 0.4263 - 45ms/epoch - 3ms/step
# Epoch 77/200
# 16/16 - 0s - loss: 0.3093 - val_loss: 0.4096 - 49ms/epoch - 3ms/step
# Epoch 78/200
# 16/16 - 0s - loss: 0.3072 - val_loss: 0.4013 - 45ms/epoch - 3ms/step
# Epoch 79/200
# 16/16 - 0s - loss: 0.3044 - val_loss: 0.4343 - 46ms/epoch - 3ms/step
# Epoch 80/200
# 16/16 - 0s - loss: 0.3047 - val_loss: 0.3997 - 45ms/epoch - 3ms/step
# Epoch 81/200
# 16/16 - 0s - loss: 0.3018 - val_loss: 0.4077 - 45ms/epoch - 3ms/step
# Epoch 82/200
# 16/16 - 0s - loss: 0.3020 - val_loss: 0.3970 - 46ms/epoch - 3ms/step
# Epoch 83/200
# 16/16 - 0s - loss: 0.3013 - val_loss: 0.4002 - 43ms/epoch - 3ms/step
# Epoch 84/200
# 16/16 - 0s - loss: 0.3014 - val_loss: 0.4278 - 43ms/epoch - 3ms/step
# Epoch 85/200
# 16/16 - 0s - loss: 0.2977 - val_loss: 0.4020 - 39ms/epoch - 2ms/step
# Epoch 86/200
# 16/16 - 0s - loss: 0.2971 - val_loss: 0.3972 - 42ms/epoch - 3ms/step
# Epoch 87/200
# 16/16 - 0s - loss: 0.2938 - val_loss: 0.3924 - 43ms/epoch - 3ms/step
# Epoch 88/200
# 16/16 - 0s - loss: 0.2976 - val_loss: 0.4178 - 44ms/epoch - 3ms/step
# Epoch 89/200
# 16/16 - 0s - loss: 0.2963 - val_loss: 0.3966 - 41ms/epoch - 3ms/step
# Epoch 90/200
# 16/16 - 0s - loss: 0.2906 - val_loss: 0.3955 - 40ms/epoch - 3ms/step
# Epoch 91/200
# 16/16 - 0s - loss: 0.2893 - val_loss: 0.3902 - 41ms/epoch - 3ms/step
# Epoch 92/200
# 16/16 - 0s - loss: 0.2898 - val_loss: 0.4012 - 40ms/epoch - 2ms/step
# Epoch 93/200
# 16/16 - 0s - loss: 0.2850 - val_loss: 0.4137 - 45ms/epoch - 3ms/step
# Epoch 94/200
# 16/16 - 0s - loss: 0.2846 - val_loss: 0.3937 - 45ms/epoch - 3ms/step
# Epoch 95/200
# 16/16 - 0s - loss: 0.2886 - val_loss: 0.3838 - 42ms/epoch - 3ms/step
# Epoch 96/200
# 16/16 - 0s - loss: 0.2925 - val_loss: 0.4000 - 41ms/epoch - 3ms/step
# Epoch 97/200
# 16/16 - 0s - loss: 0.2826 - val_loss: 0.4095 - 51ms/epoch - 3ms/step
# Epoch 98/200
# 16/16 - 0s - loss: 0.2822 - val_loss: 0.3963 - 45ms/epoch - 3ms/step
# Epoch 99/200
# 16/16 - 0s - loss: 0.2811 - val_loss: 0.4057 - 45ms/epoch - 3ms/step
# Epoch 100/200
# 16/16 - 0s - loss: 0.2786 - val_loss: 0.3995 - 46ms/epoch - 3ms/step
# Epoch 101/200
# 16/16 - 0s - loss: 0.2826 - val_loss: 0.3869 - 44ms/epoch - 3ms/step
# Epoch 102/200
# 16/16 - 0s - loss: 0.2826 - val_loss: 0.4181 - 44ms/epoch - 3ms/step
# Epoch 103/200
# 16/16 - 0s - loss: 0.2822 - val_loss: 0.4010 - 44ms/epoch - 3ms/step
# Epoch 104/200
# 16/16 - 0s - loss: 0.2762 - val_loss: 0.3846 - 44ms/epoch - 3ms/step
# Epoch 105/200
# 16/16 - 0s - loss: 0.2690 - val_loss: 0.3913 - 44ms/epoch - 3ms/step
# Epoch 106/200
# 16/16 - 0s - loss: 0.2711 - val_loss: 0.4047 - 46ms/epoch - 3ms/step
# Epoch 107/200
# 16/16 - 0s - loss: 0.2686 - val_loss: 0.3753 - 47ms/epoch - 3ms/step
# Epoch 108/200
# 16/16 - 0s - loss: 0.2738 - val_loss: 0.4079 - 48ms/epoch - 3ms/step
# Epoch 109/200
# 16/16 - 0s - loss: 0.2710 - val_loss: 0.3970 - 43ms/epoch - 3ms/step
# Epoch 110/200
# 16/16 - 0s - loss: 0.2703 - val_loss: 0.3845 - 43ms/epoch - 3ms/step
# Epoch 111/200
# 16/16 - 0s - loss: 0.2656 - val_loss: 0.4022 - 45ms/epoch - 3ms/step
# Epoch 112/200
# 16/16 - 0s - loss: 0.2703 - val_loss: 0.3825 - 47ms/epoch - 3ms/step
# Epoch 113/200
# 16/16 - 0s - loss: 0.2663 - val_loss: 0.4008 - 44ms/epoch - 3ms/step
# Epoch 114/200
# 16/16 - 0s - loss: 0.2617 - val_loss: 0.3895 - 50ms/epoch - 3ms/step
# Epoch 115/200
# 16/16 - 0s - loss: 0.2635 - val_loss: 0.4015 - 44ms/epoch - 3ms/step
# Epoch 116/200
# 16/16 - 0s - loss: 0.2640 - val_loss: 0.3870 - 43ms/epoch - 3ms/step
# Epoch 117/200
# 16/16 - 0s - loss: 0.2701 - val_loss: 0.4402 - 43ms/epoch - 3ms/step
# Epoch 118/200
# 16/16 - 0s - loss: 0.2663 - val_loss: 0.3942 - 45ms/epoch - 3ms/step
# Epoch 119/200
# 16/16 - 0s - loss: 0.2665 - val_loss: 0.3944 - 43ms/epoch - 3ms/step
# Epoch 120/200
# 16/16 - 0s - loss: 0.2617 - val_loss: 0.4137 - 44ms/epoch - 3ms/step
# Epoch 121/200
# 16/16 - 0s - loss: 0.2601 - val_loss: 0.3843 - 47ms/epoch - 3ms/step
# Epoch 122/200
# 16/16 - 0s - loss: 0.2599 - val_loss: 0.3939 - 48ms/epoch - 3ms/step
# Epoch 123/200
# 16/16 - 0s - loss: 0.2575 - val_loss: 0.3868 - 45ms/epoch - 3ms/step
# Epoch 124/200
# 16/16 - 0s - loss: 0.2593 - val_loss: 0.3901 - 39ms/epoch - 2ms/step
# Epoch 125/200
# 16/16 - 0s - loss: 0.2633 - val_loss: 0.3797 - 43ms/epoch - 3ms/step
# Epoch 126/200
# 16/16 - 0s - loss: 0.2576 - val_loss: 0.3920 - 41ms/epoch - 3ms/step
# Epoch 127/200
# 16/16 - 0s - loss: 0.2608 - val_loss: 0.3831 - 46ms/epoch - 3ms/step
# Epoch 127: early stopping

# %%
score = model.evaluate(X_test.values, y_test, verbose=1)
# print('Test accuracy: %.2f%%' % (score[1]*100))
print(y_test[:4])
# Out:
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3900
# 457    5
# 350    6
# 904    7
# 759    5
# Name: quality, dtype: int64

# %%
test_prediction = model.predict(X_test[:4])
print(test_prediction)
# Out:
# [[5.1889544]
#  [5.4060616]
#  [6.0121775]
#  [5.0413194]]

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_2 (Dense)             (None, 512)               6144
#
#  dense_3 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 6,657
# Trainable params: 6,657
# Non-trainable params: 0
# _________________________________________________________________
