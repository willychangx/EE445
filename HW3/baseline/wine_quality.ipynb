# %%
import keras
# Out:
# Using TensorFlow backend.

# %%
import numpy as np 
import pandas as pd
from sklearn.model_selection import train_test_split

from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.optimizers import Adam


from sklearn.preprocessing import StandardScaler

SEED = 2017

# %%
data = pd.read_csv('Data/winequality-red.csv', sep=';')
y = data['quality']
X = data.drop(['quality'], axis=1)
data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=SEED)

# %%
#normalize data to sample mean = 0, sample variance = 1
scaler = StandardScaler().fit(X_train)
X_train = pd.DataFrame(scaler.transform(X_train))
X_test = pd.DataFrame(scaler.transform(X_test))

# %%
batch_size = 64
n_epochs = 200
lr = 0.001

model = Sequential()
# First hidden layer with 100 hidden units
model.add(Dense(100, input_dim=X_train.shape[1], activation='relu')) 
# Second hidden layer with 50 hidden units
model.add(Dense(50, activation='relu'))
# Output layer
model.add(Dense(1, activation='linear'))


# Compile model
model.compile(loss='mse', optimizer="adam", metrics=['accuracy'])
# Out:
# 2022-04-14 21:36:51.332406: I tensorflow/core/platform/cpu_feature_guard.cc:145] This TensorFlow binary is optimized with Intel(R) MKL-DNN to use the following CPU instructions in performance critical operations:  SSE4.1 SSE4.2
# To enable them in non-MKL-DNN operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-04-14 21:36:51.332909: I tensorflow/core/common_runtime/process_util.cc:115] Creating new thread pool with default inter op setting: 8. Tune using inter_op_parallelism_threads for best performance.

# %%
callbacks = [
             EarlyStopping(monitor='val_loss', patience=20, verbose=2)
            ]

# %%
model.fit(X_train.values, y_train, batch_size=64, epochs=n_epochs, validation_split=0.2,     
             verbose=2, callbacks=callbacks)
# Out:
# Train on 1023 samples, validate on 256 samples
# Epoch 1/200
#  - 0s - loss: 23.2758 - accuracy: 9.7752e-04 - val_loss: 16.0190 - val_accuracy: 0.0039
# Epoch 2/200
#  - 0s - loss: 10.5476 - accuracy: 0.0283 - val_loss: 5.2601 - val_accuracy: 0.0703
# Epoch 3/200
#  - 0s - loss: 3.8640 - accuracy: 0.1760 - val_loss: 2.4649 - val_accuracy: 0.2773
# Epoch 4/200
#  - 0s - loss: 2.7365 - accuracy: 0.2493 - val_loss: 2.1471 - val_accuracy: 0.2578
# Epoch 5/200
#  - 0s - loss: 2.2211 - accuracy: 0.2473 - val_loss: 1.9987 - val_accuracy: 0.2969
# Epoch 6/200
#  - 0s - loss: 2.0217 - accuracy: 0.2561 - val_loss: 1.7867 - val_accuracy: 0.2852
# Epoch 7/200
#  - 0s - loss: 1.8527 - accuracy: 0.2766 - val_loss: 1.6631 - val_accuracy: 0.2891
# Epoch 8/200
#  - 0s - loss: 1.7235 - accuracy: 0.2972 - val_loss: 1.5811 - val_accuracy: 0.2930
# Epoch 9/200
#  - 0s - loss: 1.6186 - accuracy: 0.3079 - val_loss: 1.4821 - val_accuracy: 0.3164
# Epoch 10/200
#  - 0s - loss: 1.5215 - accuracy: 0.3148 - val_loss: 1.4367 - val_accuracy: 0.3164
# Epoch 11/200
#  - 0s - loss: 1.4310 - accuracy: 0.3226 - val_loss: 1.3390 - val_accuracy: 0.3164
# Epoch 12/200
#  - 0s - loss: 1.3552 - accuracy: 0.3314 - val_loss: 1.2802 - val_accuracy: 0.3359
# Epoch 13/200
#  - 0s - loss: 1.2856 - accuracy: 0.3412 - val_loss: 1.2164 - val_accuracy: 0.3555
# Epoch 14/200
#  - 0s - loss: 1.2120 - accuracy: 0.3519 - val_loss: 1.1638 - val_accuracy: 0.3516
# Epoch 15/200
#  - 0s - loss: 1.1529 - accuracy: 0.3597 - val_loss: 1.1147 - val_accuracy: 0.3594
# Epoch 16/200
#  - 0s - loss: 1.0996 - accuracy: 0.3773 - val_loss: 1.0637 - val_accuracy: 0.3789
# Epoch 17/200
#  - 0s - loss: 1.0423 - accuracy: 0.3803 - val_loss: 1.0255 - val_accuracy: 0.3789
# Epoch 18/200
#  - 0s - loss: 0.9921 - accuracy: 0.3900 - val_loss: 0.9736 - val_accuracy: 0.3984
# Epoch 19/200
#  - 0s - loss: 0.9459 - accuracy: 0.3969 - val_loss: 0.9423 - val_accuracy: 0.4219
# Epoch 20/200
#  - 0s - loss: 0.9065 - accuracy: 0.4037 - val_loss: 0.8996 - val_accuracy: 0.4336
# Epoch 21/200
#  - 0s - loss: 0.8576 - accuracy: 0.4145 - val_loss: 0.8633 - val_accuracy: 0.4414
# Epoch 22/200
#  - 0s - loss: 0.8281 - accuracy: 0.4194 - val_loss: 0.8285 - val_accuracy: 0.4414
# Epoch 23/200
#  - 0s - loss: 0.7847 - accuracy: 0.4252 - val_loss: 0.7938 - val_accuracy: 0.4727
# Epoch 24/200
#  - 0s - loss: 0.7452 - accuracy: 0.4594 - val_loss: 0.7682 - val_accuracy: 0.4570
# Epoch 25/200
#  - 0s - loss: 0.7145 - accuracy: 0.4614 - val_loss: 0.7306 - val_accuracy: 0.4766
# Epoch 26/200
#  - 0s - loss: 0.6878 - accuracy: 0.4692 - val_loss: 0.7042 - val_accuracy: 0.4883
# Epoch 27/200
#  - 0s - loss: 0.6577 - accuracy: 0.4819 - val_loss: 0.6831 - val_accuracy: 0.4844
# Epoch 28/200
#  - 0s - loss: 0.6302 - accuracy: 0.4858 - val_loss: 0.6575 - val_accuracy: 0.5000
# Epoch 29/200
#  - 0s - loss: 0.6048 - accuracy: 0.4966 - val_loss: 0.6316 - val_accuracy: 0.5039
# Epoch 30/200
#  - 0s - loss: 0.5795 - accuracy: 0.5103 - val_loss: 0.6138 - val_accuracy: 0.5156
# Epoch 31/200
#  - 0s - loss: 0.5656 - accuracy: 0.5142 - val_loss: 0.6040 - val_accuracy: 0.5195
# Epoch 32/200
#  - 0s - loss: 0.5405 - accuracy: 0.5220 - val_loss: 0.5751 - val_accuracy: 0.5156
# Epoch 33/200
#  - 0s - loss: 0.5265 - accuracy: 0.5386 - val_loss: 0.5616 - val_accuracy: 0.5273
# Epoch 34/200
#  - 0s - loss: 0.5027 - accuracy: 0.5337 - val_loss: 0.5450 - val_accuracy: 0.5391
# Epoch 35/200
#  - 0s - loss: 0.4902 - accuracy: 0.5455 - val_loss: 0.5364 - val_accuracy: 0.5508
# Epoch 36/200
#  - 0s - loss: 0.4669 - accuracy: 0.5572 - val_loss: 0.5249 - val_accuracy: 0.5586
# Epoch 37/200
#  - 0s - loss: 0.4584 - accuracy: 0.5552 - val_loss: 0.5089 - val_accuracy: 0.5586
# Epoch 38/200
#  - 0s - loss: 0.4436 - accuracy: 0.5758 - val_loss: 0.5005 - val_accuracy: 0.5625
# Epoch 39/200
#  - 0s - loss: 0.4295 - accuracy: 0.5767 - val_loss: 0.4955 - val_accuracy: 0.5781
# Epoch 40/200
#  - 0s - loss: 0.4240 - accuracy: 0.5777 - val_loss: 0.4773 - val_accuracy: 0.5664
# Epoch 41/200
#  - 0s - loss: 0.4126 - accuracy: 0.5767 - val_loss: 0.4682 - val_accuracy: 0.5586
# Epoch 42/200
#  - 0s - loss: 0.4019 - accuracy: 0.5836 - val_loss: 0.4658 - val_accuracy: 0.5859
# Epoch 43/200
#  - 0s - loss: 0.3941 - accuracy: 0.5992 - val_loss: 0.4656 - val_accuracy: 0.5938
# Epoch 44/200
#  - 0s - loss: 0.3917 - accuracy: 0.5836 - val_loss: 0.4485 - val_accuracy: 0.5938
# Epoch 45/200
#  - 0s - loss: 0.3784 - accuracy: 0.6051 - val_loss: 0.4519 - val_accuracy: 0.5820
# Epoch 46/200
#  - 0s - loss: 0.3717 - accuracy: 0.6002 - val_loss: 0.4452 - val_accuracy: 0.5820
# Epoch 47/200
#  - 0s - loss: 0.3654 - accuracy: 0.6012 - val_loss: 0.4448 - val_accuracy: 0.5781
# Epoch 48/200
#  - 0s - loss: 0.3634 - accuracy: 0.6002 - val_loss: 0.4365 - val_accuracy: 0.5938
# Epoch 49/200
#  - 0s - loss: 0.3566 - accuracy: 0.6051 - val_loss: 0.4401 - val_accuracy: 0.5820
# Epoch 50/200
#  - 0s - loss: 0.3505 - accuracy: 0.6158 - val_loss: 0.4323 - val_accuracy: 0.6016
# Epoch 51/200
#  - 0s - loss: 0.3455 - accuracy: 0.6188 - val_loss: 0.4284 - val_accuracy: 0.6016
# Epoch 52/200
#  - 0s - loss: 0.3398 - accuracy: 0.6295 - val_loss: 0.4267 - val_accuracy: 0.5938
# Epoch 53/200
#  - 0s - loss: 0.3410 - accuracy: 0.6266 - val_loss: 0.4297 - val_accuracy: 0.5938
# Epoch 54/200
#  - 0s - loss: 0.3376 - accuracy: 0.6305 - val_loss: 0.4259 - val_accuracy: 0.6016
# Epoch 55/200
#  - 0s - loss: 0.3388 - accuracy: 0.6305 - val_loss: 0.4233 - val_accuracy: 0.6055
# Epoch 56/200
#  - 0s - loss: 0.3340 - accuracy: 0.6227 - val_loss: 0.4189 - val_accuracy: 0.6055
# Epoch 57/200
#  - 0s - loss: 0.3378 - accuracy: 0.6237 - val_loss: 0.4323 - val_accuracy: 0.5859
# Epoch 58/200
#  - 0s - loss: 0.3331 - accuracy: 0.6344 - val_loss: 0.4224 - val_accuracy: 0.6133
# Epoch 59/200
#  - 0s - loss: 0.3233 - accuracy: 0.6413 - val_loss: 0.4141 - val_accuracy: 0.6133
# Epoch 60/200
#  - 0s - loss: 0.3180 - accuracy: 0.6442 - val_loss: 0.4140 - val_accuracy: 0.6211
# Epoch 61/200
#  - 0s - loss: 0.3149 - accuracy: 0.6442 - val_loss: 0.4251 - val_accuracy: 0.6133
# Epoch 62/200
#  - 0s - loss: 0.3184 - accuracy: 0.6540 - val_loss: 0.4035 - val_accuracy: 0.6133
# Epoch 63/200
#  - 0s - loss: 0.3149 - accuracy: 0.6471 - val_loss: 0.4070 - val_accuracy: 0.6289
# Epoch 64/200
#  - 0s - loss: 0.3141 - accuracy: 0.6481 - val_loss: 0.4108 - val_accuracy: 0.6289
# Epoch 65/200
#  - 0s - loss: 0.3053 - accuracy: 0.6608 - val_loss: 0.4055 - val_accuracy: 0.6055
# Epoch 66/200
#  - 0s - loss: 0.3102 - accuracy: 0.6579 - val_loss: 0.3938 - val_accuracy: 0.6211
# Epoch 67/200
#  - 0s - loss: 0.3130 - accuracy: 0.6481 - val_loss: 0.4284 - val_accuracy: 0.6133
# Epoch 68/200
#  - 0s - loss: 0.3122 - accuracy: 0.6530 - val_loss: 0.4024 - val_accuracy: 0.6250
# Epoch 69/200
#  - 0s - loss: 0.3016 - accuracy: 0.6579 - val_loss: 0.4128 - val_accuracy: 0.6055
# Epoch 70/200
#  - 0s - loss: 0.2996 - accuracy: 0.6628 - val_loss: 0.4160 - val_accuracy: 0.6133
# Epoch 71/200
#  - 0s - loss: 0.2964 - accuracy: 0.6618 - val_loss: 0.3921 - val_accuracy: 0.6211
# Epoch 72/200
#  - 0s - loss: 0.3025 - accuracy: 0.6588 - val_loss: 0.3950 - val_accuracy: 0.6289
# Epoch 73/200
#  - 0s - loss: 0.3014 - accuracy: 0.6618 - val_loss: 0.3863 - val_accuracy: 0.6172
# Epoch 74/200
#  - 0s - loss: 0.3080 - accuracy: 0.6452 - val_loss: 0.3909 - val_accuracy: 0.6289
# Epoch 75/200
#  - 0s - loss: 0.2958 - accuracy: 0.6764 - val_loss: 0.4228 - val_accuracy: 0.6094
# Epoch 76/200
#  - 0s - loss: 0.2916 - accuracy: 0.6696 - val_loss: 0.3966 - val_accuracy: 0.6289
# Epoch 77/200
#  - 0s - loss: 0.2951 - accuracy: 0.6637 - val_loss: 0.4048 - val_accuracy: 0.6133
# Epoch 78/200
#  - 0s - loss: 0.2889 - accuracy: 0.6725 - val_loss: 0.4028 - val_accuracy: 0.6289
# Epoch 79/200
#  - 0s - loss: 0.2868 - accuracy: 0.6794 - val_loss: 0.4024 - val_accuracy: 0.6172
# Epoch 80/200
#  - 0s - loss: 0.2926 - accuracy: 0.6706 - val_loss: 0.4118 - val_accuracy: 0.6211
# Epoch 81/200
#  - 0s - loss: 0.3019 - accuracy: 0.6696 - val_loss: 0.3920 - val_accuracy: 0.6289
# Epoch 82/200
#  - 0s - loss: 0.2853 - accuracy: 0.6725 - val_loss: 0.3991 - val_accuracy: 0.6523
# Epoch 83/200
#  - 0s - loss: 0.2807 - accuracy: 0.6774 - val_loss: 0.3986 - val_accuracy: 0.6133
# Epoch 84/200
#  - 0s - loss: 0.2849 - accuracy: 0.6764 - val_loss: 0.4020 - val_accuracy: 0.6406
# Epoch 85/200
#  - 0s - loss: 0.2774 - accuracy: 0.6794 - val_loss: 0.4112 - val_accuracy: 0.6367
# Epoch 86/200
#  - 0s - loss: 0.2839 - accuracy: 0.6725 - val_loss: 0.4098 - val_accuracy: 0.6172
# Epoch 87/200
#  - 0s - loss: 0.2836 - accuracy: 0.6588 - val_loss: 0.4160 - val_accuracy: 0.6211
# Epoch 88/200
#  - 0s - loss: 0.2852 - accuracy: 0.6647 - val_loss: 0.4145 - val_accuracy: 0.6445
# Epoch 89/200
#  - 0s - loss: 0.2767 - accuracy: 0.6774 - val_loss: 0.3964 - val_accuracy: 0.6406
# Epoch 90/200
#  - 0s - loss: 0.2711 - accuracy: 0.6882 - val_loss: 0.3948 - val_accuracy: 0.6406
# Epoch 91/200
#  - 0s - loss: 0.2809 - accuracy: 0.6872 - val_loss: 0.3837 - val_accuracy: 0.6289
# Epoch 92/200
#  - 0s - loss: 0.2717 - accuracy: 0.6843 - val_loss: 0.3967 - val_accuracy: 0.6289
# Epoch 93/200
#  - 0s - loss: 0.2700 - accuracy: 0.6950 - val_loss: 0.4051 - val_accuracy: 0.6445
# Epoch 94/200
#  - 0s - loss: 0.2785 - accuracy: 0.6686 - val_loss: 0.4234 - val_accuracy: 0.6094
# Epoch 95/200
#  - 0s - loss: 0.2706 - accuracy: 0.6745 - val_loss: 0.4090 - val_accuracy: 0.6172
# Epoch 96/200
#  - 0s - loss: 0.2711 - accuracy: 0.6970 - val_loss: 0.4015 - val_accuracy: 0.6367
# Epoch 97/200
#  - 0s - loss: 0.2672 - accuracy: 0.7009 - val_loss: 0.3936 - val_accuracy: 0.6484
# Epoch 98/200
#  - 0s - loss: 0.2644 - accuracy: 0.6901 - val_loss: 0.3936 - val_accuracy: 0.6445
# Epoch 99/200
#  - 0s - loss: 0.2647 - accuracy: 0.6882 - val_loss: 0.3956 - val_accuracy: 0.6484
# Epoch 100/200
#  - 0s - loss: 0.2602 - accuracy: 0.6979 - val_loss: 0.3950 - val_accuracy: 0.6289
# Epoch 101/200
#  - 0s - loss: 0.2696 - accuracy: 0.6735 - val_loss: 0.4268 - val_accuracy: 0.6289
# Epoch 102/200
#  - 0s - loss: 0.2614 - accuracy: 0.6891 - val_loss: 0.3875 - val_accuracy: 0.6484
# Epoch 103/200
#  - 0s - loss: 0.2549 - accuracy: 0.7048 - val_loss: 0.4322 - val_accuracy: 0.6094
# Epoch 104/200
#  - 0s - loss: 0.2601 - accuracy: 0.6989 - val_loss: 0.4063 - val_accuracy: 0.6445
# Epoch 105/200
#  - 0s - loss: 0.2598 - accuracy: 0.7019 - val_loss: 0.4083 - val_accuracy: 0.6328
# Epoch 106/200
#  - 0s - loss: 0.2649 - accuracy: 0.6950 - val_loss: 0.4079 - val_accuracy: 0.6289
# Epoch 107/200
#  - 0s - loss: 0.2556 - accuracy: 0.7087 - val_loss: 0.4047 - val_accuracy: 0.6406
# Epoch 108/200
#  - 0s - loss: 0.2563 - accuracy: 0.7028 - val_loss: 0.4120 - val_accuracy: 0.6367
# Epoch 109/200
#  - 0s - loss: 0.2568 - accuracy: 0.7097 - val_loss: 0.4005 - val_accuracy: 0.6328
# Epoch 110/200
#  - 0s - loss: 0.2553 - accuracy: 0.7038 - val_loss: 0.4054 - val_accuracy: 0.6211
# Epoch 111/200
#  - 0s - loss: 0.2537 - accuracy: 0.6989 - val_loss: 0.3948 - val_accuracy: 0.6523
# Epoch 00111: early stopping

# %%
score = model.evaluate(X_test.values, y_test, verbose=1)
print('Test accuracy: %.2f%%' % (score[1]*100))
print(y_test[:4])
# Out:
# 320/320 [==============================] - 0s 37us/step
# Test accuracy: 63.75%
# 457    5
# 350    6
# 904    7
# 759    5
# Name: quality, dtype: int64

# %%
test_prediction = model.predict(X_test[:4])
print(test_prediction)
# Out:
# [[5.1398015]
#  [5.6639915]
#  [6.241879 ]
#  [5.0063443]]
